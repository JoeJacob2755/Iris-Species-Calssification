# %% [markdown]
# <center><img src="https://github.com/JoeJacob2755/Picture/blob/a17bf284116c8617604734819aa3ce4dac4334d0/Iris.jpeg?raw=True"
# width="240" height="100" /></center>

# %% [markdown]
# ## -------------------TERM 3 PROJECT: CLASIFICATION OF IRIS SPECIES----------------------
#                                                  BY
#                                               Jojo Jacob
#                                             Cohort: Nov 2020

# %% [markdown]
# ### Table of Contents
# - 1. [Introduction](#section1)<br>
#     - 1.1 [About Iris](#section11)<br>
#     - 1.2 [About Project](#section12)<br>
# - 2. [Problem Statement](#section2)<br>
# - 3. [Project Approch](#section3)<br>
# - 4. [Importing Libraries and Packages](#section4)<br>
# - 5. [Creating Custom Functions](#section5)<br>
# - 6. [Data Preprocessing](#section6)<br>
#     - [Data Loading](#section61)<br>
#     - [Data Preperation](#section62)<br>
# - 7. [Data Processing](#section7)<br>
#     - 7.1 [Basic Preprocessing](#section71)<br>
#     - 7.2 [Process Individual Columns](#section72)<br>
#         - 7.2.1 [Sepal Length](#section721)<br>
#         - 7.2.2 [Sepal Width](#section722)<br>
#         - 7.2.3 [Petal Length](#section723)<br>
#         - 7.2.4 [Petal Width](#section724)<br>
#         - 7.2.5 [Species](#section725)<br>
#     - 7.3 [Obsevations](#section73)<br>
# - 8. [EDA](#section8)<br>
#    - 8.1 [Distibution of Count of Iris Species](#section81)<br>
#    - 8.2 [Comparison of Features of each Species using Histplo](#section82)<br>
#    - 8.3 [Checking for Outliers in Features](#section83)<br>
#        - 8.3.1 [Checking for Outliers in Features using Boxplots](#section831)<br>
#        - 8.3.2 [Checking for Outliers in Features within Species using Boxplots](#section832)<br>
#    - 8.4 [Checking for Corelation between Features within Species using Pair & Scatter Plots](#section84)<br>
#        - 8.4.1 [Checking for Corelation between Features within using Pair Plots](#section841)<br>
#        - 8.4.2 [Checking Corelation between Features: Reg Plots](#section842)<br>
#        - 8.4.3 [Checking Corelation between Features within Species: LM Plots](#section843)<br>
#    - 8.5 [Understanding  Features](#section85)<br>
#        - 8.5.1 [Measuring Features across Species: Swarm Plot](#section851)<br>
#        - 8.5.2 [Measuring Features within Species: Violin Plot](#section852)<br>
#    - 8.6 [Understanding Data uing Andrews Plot](#section86)<br>
#
# - 9. [Modelling](#section9)<br>
#     - 9.1 [Preparing the Test Data](#section9.1)<br>
#     - 9.2 [Feature Selection](#section9.2)<br>
#     - 9.3 [Scaling](#section9.3)<br>
#     - 9.4 [Supervised Approches](#section9.4)<br>
#         - 9.4.1 [Logistic Regression](#section941)<br>
#         - 9.4.2 [Decision Tree](#section942)<br>
#         - 9.4.3 [Naive Bayes](#section943)<br>
#     - 9.5 [Unsupervised Approches](#section95)<br>
#         - 9.5.1 [K Nearest Neighbours](#section951)<br>
#         - 9.5.2 [K Means Clustering](#section952)<br>
#     - 9.6 [Model Evaluation](#section96)<br>
# - 10. [Conclusion](#section10)<br>
#     - 10.1 [Summary](#section10.1)<br>
#     - 10.2 [Limitations of Project](#section10.2)<br>
#     - 10.3 [Lessons Learned](#section10.3)<br>
# - 11. [Acknowldgement](#section11)<br>

# %% [markdown]
# ## 1. Intoduction<a class="anchor" id="section1"></a>

# %% [markdown]
# ### 1.1 About Iris<a class="anchor" id="section11"></a>
#
# - __Irises__ are perennial plants, growing from creeping rhizomes (rhizomatous irises) or, in drier climates, from bulbs (bulbous irises). They have long, erect flowering stems which may be simple or branched, solid or hollow, and flattened or have a circular cross-section. The rhizomatous species usually have 3–10 basal sword-shaped leaves growing in dense clumps. The bulbous species have cylindrical, basal leaves.
# - __Iris__ is a genus of 260–300[1][2] species of flowering plants with showy flowers. It takes its name from the Greek word for a rainbow, which is also the name for the Greek goddess of the rainbow, Iris. Some authors state that the name refers to the wide variety of flower colors found among the many species.[3] As well as being the scientific name, iris is also widely used as a common name for all Iris species, as well as some belonging to other closely related genera. A common name for some species is 'flags', while the plants of the subgenus Scorpiris are widely known as 'junos', particularly in horticulture. It is a popular garden flower.

# %% [markdown]
# ### 1.2 About Project<a class="anchor" id="section12"></a>
# - This project is done as part of Machine Learning Term 3 Assesment. The project envisage to showcase the understanding about Data Analysis and Machine Learning Algorithms covered up to Term 3.

# %% [markdown]
# ## 2 Problem Statement<a class="anchor" id="section2"></a>
#
# - The data set contains 3 classes of 50 instances each, where each class refers to a type of Iris plant. One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# - Task is to __Predicted the class of iris plant__, These are
#     - __Iris-versicolor__
#     - __Iris-virginica__
#     - __Iris-setosa__
#
# - Variables on which the prediction is to be made isas below
#  - __sepal length__
#  - __sepal_width__
#  - __petal_length__
#  - __petal_width__

# %% [markdown]
# ## 3 Project Approch<a class="anchor" id="section3"></a>
# - The project shall be carried out in the steps enumerated below. To make the process more relaistic, the available data is split into train and test set at the very begining. Therafter, Data processing, preperation and EDA is carried out only on train set.
# - Following the above, test set will be processed and prepared for prediction
# - This will be followed by data transformation, modelling and evaluation.
# - Following models are being considered for the purpose of this project
#     - __Superwise Approch__
#         - __Logist Regression__
#         - __Decision Tree__
#         - __Naive Bayes__
#     - __Unsupervised Approch__
#         - __K Nearest Neighbours (KNN)__
#         - __K Means Clustering__
# - Model Evaluation will be carried out by comapring the accuracy and F 1 Score of each model.

# %% [markdown]
# ## 4 Importing Libraries and Function<a class="anchor" id="section4"></a>

# %%
# Pandas and Numpy
import pandas as pd
import numpy as np
import datetime as dt

# Visualisation
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import plotly.express as px
import pandas.plotting
from pandas.plotting import andrews_curves

# Satistics
from scipy.stats import zscore
from scipy.stats import norm, boxcox
from scipy import stats

# Modeling: Prerequisites
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.feature_selection import SelectFromModel
from yellowbrick.model_selection import FeatureImportances

# Models
from sklearn.ensemble import RandomForestRegressor
from sklearn.naive_bayes import GaussianNB     
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# Model Evaluation
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_curve                  
from sklearn.metrics import classification_report                   
from sklearn.metrics import plot_confusion_matrix      
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# ## 5. Creating Custom Functions<a class="anchor" id="section5"></a>
# - These functions have been created to ease of use in this notebook

# %%
# Plot_c_matrix function will enable ploting of confusion matrix of both test and train data 
# side by side for better visibility

def plot_c_matrix(model, title):
    fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, sharex = False, figsize=(20,7))
    plot_confusion_matrix(estimator = model, X = X_trains, y_true = y_train, values_format = '.7g', cmap = 'YlGnBu', ax = ax1)
    plot_confusion_matrix(estimator = model, X = X_tests, y_true = y_test, values_format = '.7g', cmap = 'YlGnBu', ax = ax2)
    
    ax1.set_title(label = 'Train Data', size = 14, color='blue', fontweight='bold')
    ax2.set_title(label = 'Test Data', size = 14, color='blue', fontweight='bold')
    
    ax1.set_ylabel('Actual', size = 14, color='green', fontweight='bold')
    ax2.set_ylabel('Actual', size = 14, color='green', fontweight='bold')
    
    ax1.tick_params(axis="x", labelsize=14, labelcolor="purple", width='bold')
    ax1.tick_params(axis="y", labelsize=14, labelcolor="purple", width='bold')
    ax2.tick_params(axis="x", labelsize=14, labelcolor="purple", width='bold')
    ax2.tick_params(axis="y", labelsize=14, labelcolor="purple", width='bold')
    
    ax1.set_xlabel('Predicted', size = 14, color='green', fontweight='bold')
    ax2.set_xlabel('Predicted', size = 14, color='green', fontweight='bold')
   
    ax1.grid(b = False)
    ax2.grid(b = False)
    plt.suptitle(t = 'Confusion Matrix :'+ title, size = 16,color='red', fontweight='bold' )
    plt.show()
    return()

# %%
#cal_score function will enable printing all relevent scores and classifiaction report for both test and train data

def cal_scores(y_test, y_test_pred,y_train, y_train_pred, model):
    print('\nAccuracy Test,  ' + model +  ': {:.4f}'.format(accuracy_score(y_test, y_test_pred)))
    print('Accuracy Train, ' + model +  ': {:.4f}\n'.format(accuracy_score(y_train, y_train_pred)))
    
    print('\nTest Data Set')
    print('Micro Precision: {:.2f}'.format(precision_score(y_test, y_test_pred, average='micro')))
    print('Micro Recall: {:.2f}'.format(recall_score(y_test, y_test_pred, average='micro')))
    print('Micro F1-score: {:.2f}\n'.format(f1_score(y_test, y_test_pred, average='micro')))
    
    print('Macro Precision: {:.2f}'.format(precision_score(y_test, y_test_pred, average='macro')))
    print('Macro Recall: {:.2f}'.format(recall_score(y_test, y_test_pred, average='macro')))
    print('Macro F1-score: {:.2f}\n'.format(f1_score(y_test, y_test_pred, average='macro')))
    
    print('Weighted Precision: {:.2f}'.format(precision_score(y_test, y_test_pred, average='weighted')))
    print('Weighted Recall: {:.2f}'.format(recall_score(y_test, y_test_pred, average='weighted')))
    print('Weighted F1-score: {:.2f}'.format(f1_score(y_test, y_test_pred, average='weighted')))
    
    print('\nTrain Data Set')
    print('Micro Precision: {:.2f}'.format(precision_score(y_train, y_train_pred, average='micro')))
    print('Micro Recall: {:.2f}'.format(recall_score(y_train, y_train_pred, average='micro')))
    print('Micro F1-score: {:.2f}\n'.format(f1_score(y_train, y_train_pred, average='micro')))
    
    print('Macro Precision: {:.2f}'.format(precision_score(y_train, y_train_pred, average='macro')))
    print('Macro Recall: {:.2f}'.format(recall_score(y_train, y_train_pred, average='macro')))
    print('Macro F1-score: {:.2f}\n'.format(f1_score(y_train, y_train_pred, average='macro')))
    
    print('Weighted Precision: {:.2f}'.format(precision_score(y_train, y_train_pred, average='weighted')))
    print('Weighted Recall: {:.2f}'.format(recall_score(y_train, y_train_pred, average='weighted')))
    print('Weighted F1-score: {:.2f}'.format(f1_score(y_train, y_train_pred, average='weighted')))
    
    print('\nClassification Report\n')
    print('                    Training Report          ')
    print(classification_report(y_train, y_train_pred))
    print('                    Testing Report           ')
    print(classification_report(y_test, y_test_pred))
    return()

# %% [markdown]
# ## 6. Data Preprocessing<a class="anchor" id="section6"></a>
# - Load Data
# - Split data to Train and Test
# - Check for missing data
# - Check for dtypes
# - Describe data

# %% [markdown]
# ### 6.1 Data Loading<a class="anchor" id="section61"></a>
# - Iris data base was downloaded into the local folder as csv file and is loaded into dataframe ir
# - There are total of 150 rows in the dataset

# %%
ir =pd.read_csv('/Users/jojojacob/Documents/INSAID /Term 3 Project/Iris.csv')
print(ir.shape)
# Out:
# (150, 6)

# %%
ir.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### 6.2  Data Preperation<a class="anchor" id="section62"></a>
# - Split Data to train and test
#  - ir_train
#  - ir_test
# - Check Missing Data
# - Check dtypes consistency
# - Dwscribe Data

# %%
#Split
ir_train, ir_test = train_test_split(ir, test_size=0.20, random_state=1)

# %%
ir_train = ir_train.reset_index(drop=True)
print(ir_train.shape)
ir_train.head(2)
# Out:
# (120, 6)
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0   92            6.1           3.0            4.6           1.4
# 1  136            7.7           3.0            6.1           2.3
#
#            Species
# 0  Iris-versicolor
# 1   Iris-virginica

# %%
ir_test = ir_test.reset_index(drop=True)
print(ir_test.shape)
ir_test.head(2)
# Out:
# (30, 6)
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0  15            5.8           4.0            1.2           0.2
# 1  99            5.1           2.5            3.0           1.1
#
#            Species
# 0      Iris-setosa
# 1  Iris-versicolor

# %%
# Gain basic inforamtion on data
ir_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             120 non-null    int64
#  1   SepalLengthCm  120 non-null    float64
#  2   SepalWidthCm   120 non-null    float64
#  3   PetalLengthCm  120 non-null    float64
#  4   PetalWidthCm   120 non-null    float64
#  5   Species        120 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 5.8+ KB

# %%
# Check for missing data
ir_train.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
summary = ir_train.describe().transpose()
summary
# Out:
#                count       mean        std  min    25%    50%      75%    max
# Id             120.0  76.575000  44.384050  1.0  38.75  76.00  115.250  150.0
# SepalLengthCm  120.0   5.838333   0.832752  4.3   5.10   5.80    6.400    7.7
# SepalWidthCm   120.0   3.015000   0.417002  2.0   2.80   3.00    3.300    4.4
# PetalLengthCm  120.0   3.810833   1.770951  1.0   1.60   4.35    5.125    6.9
# PetalWidthCm   120.0   1.218333   0.777843  0.1   0.30   1.30    1.800    2.5

# %% [markdown]
# ### 6.3  Obsevations: Data Preperation<a class="anchor" id="section63"></a>
# - Iris Data has 150 rows and 6 columns
#     - Train Set is named ir_train
#     - Test Set  is named ir_test
# - Train set has __120__ rows and test set has __30__ rows
# - Id Column is an identification variable and is dropped
# - Species is the target variable
# - There are four exploratory variables
#     -__Sepal Length__
#     -__Sepal Width__
#     -__Petal Length__
#     -__Petal Width__
# - There are no missing values
# - The distribution of exlporatory variables seems normal

# %% [markdown]
# ## 7  Data Processing<a class="anchor" id="section67"></a>
# - Drop Unwanted columns
# - Rename columns for ease of use and understanding
# - Process individual Columns fo data consistency, typos and other errors
#     - Unique values count
#     - Unique values
#     - Plot numerical values
# - Check for correlation between exploratory variables

# %% [markdown]
# ### 7.1 Basic Processing<a class="anchor" id="section71"></a>

# %%
# Id is an iddentification variable and hence being dropped
ir_train.drop('Id', axis = 1, inplace = True)

# %%
# Convert columns to lower case for better understanding and ease
ir_train.columns = ir_train.columns.str.lower()

# %%
# Remane columns for better understanding and ease
ir_train.rename(columns={'sepallengthcm':'sepal_length','sepalwidthcm':'sepal_width','petallengthcm':'petal_length','petalwidthcm':'petal_width'}, inplace=True)

# %%
ir_train.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width          species
# 0           6.1          3.0           4.6          1.4  Iris-versicolor
# 1           7.7          3.0           6.1          2.3   Iris-virginica
# 2           5.6          2.5           3.9          1.1  Iris-versicolor
# 3           6.4          2.8           5.6          2.1   Iris-virginica
# 4           5.8          2.8           5.1          2.4   Iris-virginica

# %% [markdown]
# ### 7.2 Processing Individual Columns<a class="anchor" id="section72"></a>

# %% [markdown]
# #### 7.2.1 Sepal Length (sepal_length)<a class="anchor" id="section721"></a>

# %%
# # of Unique Vaules
ir_train['sepal_length'].nunique()
# Out:
# 33

# %%
# Unique Values
ir_train['sepal_length'].unique()
# Out:
# array([6.1, 7.7, 5.6, 6.4, 5.8, 5.3, 5.5, 5.2, 6.5, 6.7, 6.8, 5.1, 6. ,
#        6.3, 6.6, 5.7, 5. , 4.8, 6.9, 7.3, 6.2, 4.7, 4.6, 5.4, 4.9, 4.4,
#        5.9, 7.4, 7.6, 7.2, 4.5, 4.3, 7. ])

# %%
# Distribution of Sepal Length
plt.figure(figsize=(8,6))
sns.histplot(ir_train, x = 'sepal_length', kde=True, color='blue')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %% [markdown]
# #### 7.2.2 Sepal Width (sepal_width)<a class="anchor" id="section722"></a>

# %%
# # of Unique Vaules
ir_train['sepal_width'].nunique()
# Out:
# 20

# %%
# Unique Vaules
ir_train['sepal_width'].unique()
# Out:
# array([3. , 2.5, 2.8, 3.7, 2.3, 3.4, 3.5, 2.2, 2.9, 2.6, 3.8, 3.6, 2.7,
#        3.1, 3.2, 3.3, 4.1, 4.4, 2.4, 2. ])

# %%
# Distribution of Sepal Length
plt.figure(figsize=(8,6))
sns.histplot(ir_train, x = 'sepal_width', kde=True, color='blue')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Count'>

# %% [markdown]
# #### 7.2.3 Petal Length  (petal_length)<a class="anchor" id="section723"></a>

# %%
# # of Unique Vaules
ir_train['petal_length'].nunique()
# Out:
# 40

# %%
# Unique Vaules
ir_train['petal_length'].unique()
# Out:
# array([4.6, 6.1, 3.9, 5.6, 5.1, 1.5, 4. , 1.4, 5.8, 5.5, 5. , 6.9, 1.7,
#        1.3, 6.7, 5.4, 6.3, 4.8, 4.5, 4.2, 1.6, 4.9, 4.4, 5.7, 4.3, 3.3,
#        6. , 5.3, 4.1, 6.6, 5.2, 3.6, 3.8, 1.9, 5.9, 1.1, 3.7, 3.5, 1. ,
#        4.7])

# %%
# Distribution of Sepal Length
plt.figure(figsize=(8,6))
sns.histplot(ir_train, x = 'petal_length', color='blue', kde=True)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %% [markdown]
# #### 7.2.4 Petal Length  (petal_length)<a class="anchor" id="section724"></a>

# %%
# # of Unique Vaules
ir_train['petal_width'].nunique()
# Out:
# 22

# %%
# Unique Vaules
ir_train['petal_width'].unique()
# Out:
# array([1.4, 2.3, 1.1, 2.1, 2.4, 0.2, 1.3, 1.5, 1.8, 0.3, 2.2, 1.6, 2. ,
#        1.2, 0.1, 2.5, 1. , 1.9, 0.5, 0.4, 0.6, 1.7])

# %%
# Distribution of Sepal Length
plt.figure(figsize=(8,6))
sns.histplot(ir_train, x = 'petal_width', color='blue', kde=True)
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='Count'>

# %% [markdown]
# #### 7.2.5 Species  (species): Target Variable<a class="anchor" id="section725"></a>

# %%
# # of Unique Vaules
ir_train['species'].nunique()
# Out:
# 3

# %%
# Unique Vaules
ir_train['species'].unique()
# Out:
# array(['Iris-versicolor', 'Iris-virginica', 'Iris-setosa'], dtype=object)

# %%
# Checking for multicolinearity among X variables in train data set
# use heatmap
plt.figure (figsize=(10,7))
correlation_ir_train = sns.heatmap(ir_train.corr(), annot = True, cmap='PiYG')
correlation_ir_train
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 7.3 Observations<a class="anchor" id="section73"></a>
# - Data is consistent
# - Distribution of Sepal Length and Width are normal, whereas that of Petal length and width are not normal
# - Correlations
#     - Sepal Length is highly corelated to petal width and petal length
#     - Sepal Length has no correlation with Sepal Width
#     - Sepal Width has no correlation with any other data

# %% [markdown]
# ## 8 EDA<a class="anchor" id="section8"></a>
# - Distribution of species in dataset
# -

# %% [markdown]
# ### 8.1 Distibution of Count of Iris Species<a class="anchor" id="section81"></a>

# %%
ir_train["species"].value_counts()
# Out:
# Iris-virginica     44
# Iris-setosa        39
# Iris-versicolor    37
# Name: species, dtype: int64

# %%
# Count plot and doughnut plot are used to show distribution of species in data set
fig, ax = plt.subplots(1,2, figsize = [15, 8])

space = [0.0,0.01,0.01]
colors = ['#ff9999','#66b3ff','#99ff99']

sns.countplot(x = 'species', data = ir_train, ax=ax[0],color='orange')
ir_train['species'].value_counts().plot(kind = 'pie', ax=ax[1], explode = space, fontsize = 14, autopct = '%3.1f%%', wedgeprops = dict(width=0.25), 
                                      shadow = True, startangle = 160, figsize = [15, 8], legend = True, colors=colors)
plt.legend(ir_train.species)

plt.suptitle(t = 'Frequency & Proportion of Iris Species', color='red', y = 1.02, size = 16)

ax[0].set_xlabel(xlabel = 'Species', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0].set_ylabel(ylabel = 'Count', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0].set_title(label = 'Count of Species', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0].tick_params(axis="x", labelsize=14, labelcolor="purple", rotation = 0)
space = [0.0,0.05,0.05]

ax[1].set_title(label = 'Proportion of Species', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1].set_ylabel('', size = 14)
plt.tight_layout(pad = 3.0)

plt.show()

# %% [markdown]
# ### 8.2 Comparison of Features of each Species using Histplo <a class="anchor" id="section82"></a>

# %%
f, ax = plt.subplots(2,2, figsize=(15,9))
sns.histplot(data=ir_train, x="petal_length", hue="species", palette ='rainbow', kde=True,ax=ax[0,0])
sns.histplot(data=ir_train, x="petal_width", hue="species", palette ='flare_r',kde=True,ax=ax[1,0])
sns.histplot(data=ir_train, x="sepal_length", hue="species", palette ='ocean',kde=True,ax=ax[0,1])
sns.histplot(data=ir_train, x="sepal_width", hue="species", palette ='winter',kde=True,ax=ax[1,1])

plt.suptitle(t = 'Feature Comparison', color='red', y = 1.02, size = 16)

ax[0,0].set_xlabel(xlabel = '', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,0].set_ylabel(ylabel = 'Length', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,0].set_title(label = 'Petal Length', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,0].tick_params(axis="x", labelsize=14, labelcolor="purple", width='bold')

ax[0,1].set_xlabel(xlabel = '', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,1].set_ylabel(ylabel = 'Width', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,1].set_title(label = 'Petal Width', size = 16, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,1].tick_params(axis="x", labelsize=14, labelcolor="purple", width='bold')

ax[1,0].set_xlabel(xlabel = '', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,0].set_ylabel(ylabel = 'Length', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,0].set_title(label = 'Sepal Length', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,0].tick_params(axis="x", labelsize=14, labelcolor="purple", width='bold')

ax[1,1].set_xlabel(xlabel = '', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,1].set_ylabel(ylabel = 'Width', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,1].set_title(label = 'Sepal Width', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,1].tick_params(axis="x", labelsize=14, labelcolor="purple", width='bold')
plt.show()

# %% [markdown]
# #### Observation
# - Within each species the features are normally distributed
# - Iris Setosa shows significant vareiation in Petal and Sepal length compared to other two species.
# - Iris Setosa shows notable diffrence in petal width compared to other two species.

# %% [markdown]
# ### 8.3 Checking for Outliers in Features<a class="anchor" id="section83"></a>

# %% [markdown]
# ### 8.3.1 Checking for Outliers in Features using Boxplots<a class="anchor" id="section831"></a>

# %%
# Using Box Plot to find outliers if any
ir_train.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# ### 8.3.2 Checking for Outliers in Features within Species using Boxplots<a class="anchor" id="section832"></a>

# %%
f, ax = plt.subplots(2,2, figsize=(20,10))

#sns.set(style="whitegrid", palette="GnBu_d", rc={'figure.figsize':(11.7,8.27)})

sns.boxplot(x="species", y="sepal_length", data=ir_train, ax = ax[0,0])
sns.boxplot(x="species", y="sepal_width", data=ir_train, ax = ax[0,1])
sns.boxplot(x="species", y="petal_length", data=ir_train, ax = ax[1,0])
sns.boxplot(x="species", y="petal_width", data=ir_train, ax = ax[1,1])

plt.suptitle(t = 'Features', color='red', y = 1.02, size = 16)

ax[0,0].set_xlabel(xlabel = '', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,0].set_ylabel(ylabel = 'Length', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,0].set_title(label = 'Sepal Length', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,0].tick_params(axis="x", labelsize=14, labelcolor="purple", width='bold')

ax[0,1].set_xlabel(xlabel = '', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,1].set_ylabel(ylabel = 'Width', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,1].set_title(label = 'Sepal Width', size = 16, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,1].tick_params(axis="x", labelsize=14, labelcolor="purple", width='bold')

ax[1,0].set_xlabel(xlabel = '', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,0].set_ylabel(ylabel = 'Length', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,0].set_title(label = 'Petal Length', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,0].tick_params(axis="x", labelsize=14, labelcolor="purple", width='bold')

ax[1,1].set_xlabel(xlabel = '', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,1].set_ylabel(ylabel = 'Width', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,1].set_title(label = 'Petal Width', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,1].tick_params(axis="x", labelsize=14, labelcolor="purple", width='bold')


# Show the plot
plt.show()

# %% [markdown]
# #### Observation
# - There are no major outliers in any of the the features between features
# - There are no major outliers in any feature within each species.

# %% [markdown]
# ### 8.4. Checking for Corelation between Features within Species using Pair & Scatter Plots<a class="anchor" id="section84"></a>

# %% [markdown]
# ### 8.4.1 Checking for Corelation between Features within using Pair Plots<a class="anchor" id="section841"></a>

# %%
sns.pairplot(ir_train, hue="species", kind='reg', palette="winter", markers=["o", "s", "D"])
sns.despine()
plt.show()

# %% [markdown]
# ### 8.4.2 Checking Corelation between Features: Reg Plots<a class="anchor" id="section842"></a>

# %%
plt.figure(figsize=(15,12))
plt.subplot(2,2,1)
sns.regplot(x='sepal_length', y= 'sepal_width', data= ir_train, color='red');
sns.regplot(x='sepal_length', y= 'petal_length', data= ir_train, color='green');
sns.regplot(x='sepal_length', y= 'petal_width', data= ir_train, color='blue');
plt.title('Sepal Length Vs Other Features', color = 'blue', fontweight = 'bold', fontsize =14)
plt.xlabel('Sepal Length', color = 'blue', fontweight = 'bold', fontsize =14)
plt.ylabel('Petal Width', color = 'green', fontweight = 'bold', fontsize =14)
plt.tick_params(labelcolor='purple', labelsize=14)
plt.legend(labels=['sepal length vs sepal width','sepal length vs petal length','sepal length vs petal width'], frameon =True)
plt.subplot(2,2,2)
sns.regplot(x='sepal_width', y= 'petal_width', data= ir_train, color='red');
sns.regplot(x='sepal_width', y= 'petal_length', data= ir_train, color='orange');
sns.regplot(x='petal_width', y= 'petal_length', data= ir_train, color='purple');
plt.title('Sepal Length Vs Other Features', color = 'blue', fontweight = 'bold', fontsize =14)
plt.xlabel('Petal Width', color = 'blue', fontweight = 'bold', fontsize =14)
plt.ylabel('Petal Length', color = 'green', fontweight = 'bold', fontsize =14)
plt.tick_params(labelcolor='purple', labelsize=14)
plt.legend(labels=['Sepal Width vs Petal Width','Sepal Width vs Petal Length','Petal Width vs Petal Length'], frameon =True)

# %% [markdown]
# ### 8.4.3 Checking Corelation between Features within Species: LM Plots <a class="anchor" id="section843"></a>

# %%
sns.lmplot(x='sepal_length', y= 'sepal_width', data= ir_train,hue='species',col='species', palette='flare');
sns.lmplot(x='sepal_length', y= 'petal_length',data= ir_train,hue='species',col='species',palette='rainbow');
sns.lmplot(x='sepal_length', y= 'petal_width', data= ir_train,hue='species',col='species',palette='winter');
sns.lmplot(x='sepal_width',  y= 'petal_width', data= ir_train,hue='species',col='species',palette='flare');
sns.lmplot(x='sepal_width',  y= 'petal_length', data= ir_train,hue='species',col='species',palette='rainbow');
sns.lmplot(x='petal_width',  y= 'petal_length', data= ir_train,hue='species',col='species',palette='winter');

# %% [markdown]
# #### Observation
# - Correlation or lack of it between features are seen to be similar between and within species
# - Sepal Length has high correlation with Petal Length
# - Sepal Length has no correlation to Sepal Width
# - Sepal Length has no correlation to Petal Width
# - Sepal Width  has some negative correlation to Petal Width
# - Petal Width  has high correlation to Petal Length

# %% [markdown]
# ### 8.5 Understanding  Features<a class="anchor" id="section85"></a>

# %% [markdown]
# ### 8.5.1 Measuring Features across Species: Swarm Plot<a class="anchor" id="section851"></a>

# %%
sns.set(style="whitegrid", palette="GnBu_d", rc={'figure.figsize':(11,8)})

# "Melt" the dataset
ir_train2 = pd.melt(ir_train, "species", var_name="measurement")

# Draw a categorical scatterplot
sns.swarmplot(x="measurement", y="value", hue="species",palette="GnBu_d", data=ir_train2)

plt.title('Measurement of Features Within Each Species: Swarm Plot', color = 'red', fontweight = 'bold', fontsize =14)
plt.xlabel('Measurement', color = 'blue', fontweight = 'bold', fontsize =14)
plt.ylabel('Value', color = 'blue', fontweight = 'bold', fontsize =14)
plt.tick_params(axis='x',labelcolor='purple', labelsize=14)
plt.tick_params(axis='y',labelcolor='green', labelsize=14)
plt.legend(frameon=True,title='Species')

plt.show()

# %% [markdown]
# ### 8.5.2 Measuring Features within Species: Violin Plot<a class="anchor" id="section852"></a>

# %%
plt.figure(figsize=(15,10))
plt.suptitle(t = 'Comparison of Features using Violin Plot', color='red', y = 1.02, size = 16)
plt.subplot(2,2,1)
sns.violinplot(x='species',y='sepal_length',data=ir_train,palette="rainbow")
plt.title('Sepal Length', color = 'blue', fontweight = 'bold', fontsize =14)
plt.xlabel('', color = 'blue', fontweight = 'bold', fontsize =14)
plt.ylabel('Length', color = 'green', fontweight = 'bold', fontsize =14)
plt.tick_params(labelcolor='purple', labelsize=14)
plt.subplot(2,2,2)
sns.violinplot(x='species',y='sepal_width',data=ir_train,palette="rainbow")
plt.title('Sepal Width', color = 'blue', fontweight = 'bold', fontsize =14)
plt.xlabel('', color = 'blue', fontweight = 'bold', fontsize =14)
plt.ylabel('Width', color = 'green', fontweight = 'bold', fontsize =14)
plt.tick_params(labelcolor='purple', labelsize=14)
plt.subplot(2,2,3)
sns.violinplot(x='species',y='petal_length',data=ir_train,palette="rainbow")
plt.title('Petal Length', color = 'blue', fontweight = 'bold', fontsize =14)
plt.xlabel('', color = 'blue', fontweight = 'bold', fontsize =14)
plt.ylabel('Length', color = 'green', fontweight = 'bold', fontsize =14)
plt.tick_params(labelcolor='purple', labelsize=14)
plt.subplot(2,2,4)
sns.violinplot(x='species',y='petal_width',data=ir_train,palette="rainbow")
plt.title('Petal Width', color = 'blue', fontweight = 'bold', fontsize =14)
plt.xlabel('', color = 'blue', fontweight = 'bold', fontsize =14)
plt.ylabel('Width', color = 'green', fontweight = 'bold', fontsize =14)
plt.tick_params(labelcolor='purple', labelsize=14)

# %% [markdown]
# #### Observations
# - The class "Iris-sentosa" seems to have less petal,sepal length and petal width.However it has higher sepal width or in other words it's width is varied from low to high but majority on the higher side
# - The class "Iris-virginica"  has high sepal length, petal length, petal width  but medium ranged sepal width.
# - From the above two observations it is understood that "Iris-sentosa"  and "Iris-virginica" is linearly seperable.
# - The class "Iris-versicolor" lies in the mid range for all the attributes.

# %% [markdown]
# ### 8.6 Understanding Data uing Andrews Plot<a class="anchor" id="section86"></a>
# - Most data that are collected are multivariate in nature, and much of them can be regarded as continuous. In the initial stages of analysis, graphic displays can be used to explore the data, but for multivariate data, traditional histograms or two- or three-dimensional scatter plots may miss complex relationships that exist in the data set.
# - A first step in any investigation of data is to create simple summaries and graphs so as to obtain a better understanding of the nature of the data before analysis and also check for outliers or unusual observations. However, the production of univariate or bivariate summary statistics (e.g., means, correlations) or of histograms and two-dimensional scatter plots to graphically display the data may hide more complex relationships existing in the multivariate data set.
# - __Andrews Curve__ is a great tool for analysing the complex relationships in multivariate analysis.
# - It is being used to acertain the possible groups/custers in unsupervised machine learning approch.
# - Formula used is __x(t)= x1 2 + x2 sin(t)+ x3 cos(t)+ x4 sin(2t)+ x5 cos(2t)+ x6 sin(3t)+ x7 cos(3t)+....__

# %%
andrews_curves(ir_train, "species")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Observations
# - There are 3 distinct classes/groups in the data set
# - There are no ouliers in the dataset
# - Class/Group fromation is fairly straight forward and simple

# %% [markdown]
# ## 9 Modelling<a class="anchor" id="section9"></a>

# %% [markdown]
# ### 9.1 Preparing the Test Data<a class="anchor" id="section91"></a>
# - The Test data has to processed in the same manner as that of train data.

# %%
ir_test.head()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0   15            5.8           4.0            1.2           0.2
# 1   99            5.1           2.5            3.0           1.1
# 2   76            6.6           3.0            4.4           1.4
# 3   17            5.4           3.9            1.3           0.4
# 4  132            7.9           3.8            6.4           2.0
#
#            Species
# 0      Iris-setosa
# 1  Iris-versicolor
# 2  Iris-versicolor
# 3      Iris-setosa
# 4   Iris-virginica

# %%
# Droppig, reformat and rename the columns
ir_test.drop('Id', axis = 1, inplace = True)
ir_test.columns = ir_train.columns.str.lower()
ir_test.rename(columns={'sepallengthcm':'sepal_length','sepalwidthcm':'sepal_width','petallengthcm':'petal_length','petalwidthcm':'petal_width'}, inplace=True)

# %%
ir_test.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width          species
# 0           5.8          4.0           1.2          0.2      Iris-setosa
# 1           5.1          2.5           3.0          1.1  Iris-versicolor

# %% [markdown]
# ### 9.2 Feature Selection<a class="anchor" id="section92"></a>

# %%
# There are various ways to do the feature selection, here is one
# Train Data
X_train = ir_train.loc[:, ir_train.columns != 'species']
y_train = ir_train['species']

#Test Data
X_test = ir_test.loc[:, ir_test.columns != 'species']
y_test = ir_test['species']

# %%
print('X_train :', X_train.shape)
print('y_train :', y_train.shape)
print('X_test  :', X_test.shape)
print('y_test  :', y_test.shape)
print(y_test.dtype)
print(y_train.dtype)
# Out:
# X_train : (120, 4)
# y_train : (120,)
# X_test  : (30, 4)
# y_test  : (30,)
# object
# object

# %% [markdown]
# ### 9.3 Scaling of Data<a class="anchor" id="section93"></a>
# - Scaling of data is essential and prerequesite to sucessful model creation.
# - __Standard Scalar__ is used.

# %%
#fitting is determining what to do
#transforming - actually doing it

scaler = StandardScaler() # cleate an object
scaler.fit(X_train) #what should be the multiplication factor
X_trains = scaler.transform(X_train) #actually multiplies
X_tests  = scaler.transform(X_test)

# %% [markdown]
# ### 9.4 Modelling using Supervised Approach<a class="anchor" id="section94"></a>
# - __Logistic Regression__
# - __Decisison Tree__
# - __Naive Bayes__

# %% [markdown]
# ### 9.4.1 Logistic Regression<a class="anchor" id="section941"></a>

# %%
LogReg = LogisticRegression()
LogReg.fit(X_trains, y_train)
y_pred_train_logreg = LogReg.predict(X_trains)
y_pred_test_logreg  = LogReg.predict(X_tests)

# %%
accuracy_score_logreg = accuracy_score(y_test,y_pred_test_logreg)
print('Accuracy score for test data log reg is:', accuracy_score_logreg)
# Out:
# Accuracy score for test data log reg is: 0.9666666666666667

# %%
plot_c_matrix(LogReg, 'Logistic Regression')
# Out:
# ()

# %%
cal_scores(y_test,y_pred_test_logreg, y_train, y_pred_train_logreg, 'Logistic Regression')
# Out:
# Accuracy Test,  Logistic Regression: 0.9667
# Accuracy Train, Logistic Regression: 0.9750
#
#
# Test Data Set
# Micro Precision: 0.97
# Micro Recall: 0.97
# Micro F1-score: 0.97
#
# Macro Precision: 0.95
# Macro Recall: 0.97
# Macro F1-score: 0.96
#
# Weighted Precision: 0.97
# Weighted Recall: 0.97
# Weighted F1-score: 0.97
#
# Train Data Set
# Micro Precision: 0.97
# Micro Recall: 0.97
# Micro F1-score: 0.97
#
# Macro Precision: 0.98
# Macro Recall: 0.97
# Macro F1-score: 0.98
#
# Weighted Precision: 0.98
# Weighted Recall: 0.97
# Weighted F1-score: 0.97
#
# Classification Report
#
#                     Training Report
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        39
# Iris-versicolor       0.97      0.95      0.96        37
#  Iris-virginica       0.96      0.98      0.97        44
#
#        accuracy                           0.97       120
#       macro avg       0.98      0.97      0.98       120
#    weighted avg       0.98      0.97      0.97       120
#
#                     Testing Report
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.92      0.96        13
#  Iris-virginica       0.86      1.00      0.92         6
#
#        accuracy                           0.97        30
#       macro avg       0.95      0.97      0.96        30
#    weighted avg       0.97      0.97      0.97        30
# ()

# %% [markdown]
# ### 9.4.2 Decision Tree<a class="anchor" id="section942"></a>

# %%
from sklearn import tree
dt = tree.DecisionTreeClassifier(random_state = 0)
dt.fit(X_trains, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
y_pred_train_dt = dt.predict(X_trains)  
y_pred_test_dt = dt.predict(X_tests)

# %%
accuracy_score_dt = accuracy_score(y_test, y_pred_test_dt)
print('Accuracy score for test data log reg is:', accuracy_score_dt)
# Out:
# Accuracy score for test data log reg is: 0.9666666666666667

# %%
plot_c_matrix(dt, 'Decision Tree')
# Out:
# ()

# %%
cal_scores(y_test,y_pred_test_dt, y_train, y_pred_train_dt, 'Decision Tree')
# Out:
# Accuracy Test,  Decision Tree: 0.9667
# Accuracy Train, Decision Tree: 1.0000
#
#
# Test Data Set
# Micro Precision: 0.97
# Micro Recall: 0.97
# Micro F1-score: 0.97
#
# Macro Precision: 0.95
# Macro Recall: 0.97
# Macro F1-score: 0.96
#
# Weighted Precision: 0.97
# Weighted Recall: 0.97
# Weighted F1-score: 0.97
#
# Train Data Set
# Micro Precision: 1.00
# Micro Recall: 1.00
# Micro F1-score: 1.00
#
# Macro Precision: 1.00
# Macro Recall: 1.00
# Macro F1-score: 1.00
#
# Weighted Precision: 1.00
# Weighted Recall: 1.00
# Weighted F1-score: 1.00
#
# Classification Report
#
#                     Training Report
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        39
# Iris-versicolor       1.00      1.00      1.00        37
#  Iris-virginica       1.00      1.00      1.00        44
#
#        accuracy                           1.00       120
#       macro avg       1.00      1.00      1.00       120
#    weighted avg       1.00      1.00      1.00       120
#
#                     Testing Report
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.92      0.96        13
#  Iris-virginica       0.86      1.00      0.92         6
#
#        accuracy                           0.97        30
#       macro avg       0.95      0.97      0.96        30
#    weighted avg       0.97      0.97      0.97        30
# ()

# %% [markdown]
# ### 9.4.3 Naive Bayes<a class="anchor" id="section943"></a>
# - Use Gaussian NB algorithm.

# %%
naive = GaussianNB()
naive.fit(X_trains, y_train)
y_pred_train_nb = naive.predict(X_trains)
y_pred_test_nb  = naive.predict(X_tests)

# %%
accuracy_score_nb = accuracy_score(y_test,y_pred_test_nb)
print('Accuracy score for test data naive bayes is:', accuracy_score_nb)
# Out:
# Accuracy score for test data naive bayes is: 0.9666666666666667

# %%
plot_c_matrix(naive, 'Naive Bayes')
# Out:
# ()

# %%
cal_scores(y_test,y_pred_test_nb, y_train, y_pred_train_nb, 'Naive Bayes')
# Out:
# Accuracy Test,  Naive Bayes: 0.9667
# Accuracy Train, Naive Bayes: 0.9500
#
#
# Test Data Set
# Micro Precision: 0.97
# Micro Recall: 0.97
# Micro F1-score: 0.97
#
# Macro Precision: 0.95
# Macro Recall: 0.97
# Macro F1-score: 0.96
#
# Weighted Precision: 0.97
# Weighted Recall: 0.97
# Weighted F1-score: 0.97
#
# Train Data Set
# Micro Precision: 0.95
# Micro Recall: 0.95
# Micro F1-score: 0.95
#
# Macro Precision: 0.95
# Macro Recall: 0.95
# Macro F1-score: 0.95
#
# Weighted Precision: 0.95
# Weighted Recall: 0.95
# Weighted F1-score: 0.95
#
# Classification Report
#
#                     Training Report
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        39
# Iris-versicolor       0.92      0.92      0.92        37
#  Iris-virginica       0.93      0.93      0.93        44
#
#        accuracy                           0.95       120
#       macro avg       0.95      0.95      0.95       120
#    weighted avg       0.95      0.95      0.95       120
#
#                     Testing Report
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.92      0.96        13
#  Iris-virginica       0.86      1.00      0.92         6
#
#        accuracy                           0.97        30
#       macro avg       0.95      0.97      0.96        30
#    weighted avg       0.97      0.97      0.97        30
# ()

# %% [markdown]
# ### 9.5 Unsupervised Approches<a class="anchor" id="section95"></a>

# %% [markdown]
# ### 9.5.1 K N N<a class="anchor" id="section951"></a>

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(X_trains,y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred_test_knn=knn.predict(X_tests)
y_pred_train_knn=knn.predict(X_trains)
accuracy_score_test_knn = accuracy_score(y_test, y_pred_test_knn)
accuracy_score_train_knn = accuracy_score(y_train, y_pred_train_knn)

print("Accuracy of the KNN Test Data is : {} %".format(accuracy_score_test_knn))
print("Accuracy of the KNN Train Data is: {} %".format(accuracy_score_train_knn))
# Out:
# Accuracy of the KNN Test Data is : 0.9666666666666667 %
# Accuracy of the KNN Train Data is: 0.9583333333333334 %

# %%
plot_c_matrix(knn, 'KNN')
# Out:
# ()

# %% [markdown]
# ### 9.5.2 K Means Clustering<a class="anchor" id="section952"></a>

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.mixture import GaussianMixture #For GMM clustering

# %%
ir_train.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width          species
# 0           6.1          3.0           4.6          1.4  Iris-versicolor
# 1           7.7          3.0           6.1          2.3   Iris-virginica
# 2           5.6          2.5           3.9          1.1  Iris-versicolor
# 3           6.4          2.8           5.6          2.1   Iris-virginica
# 4           5.8          2.8           5.1          2.4   Iris-virginica

# %%
ir_k = ir_train[['sepal_length','sepal_length','petal_length','petal_width']]

# %%
#Finding the optimum number of clusters for k-means classification
from sklearn.cluster import KMeans
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(X_trains)
    wcss.append(kmeans.inertia_)

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') #within cluster sum of squares
plt.show()

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
kmeans = kmeans.fit(X_trains)
y_pred_train_kmeans = kmeans.predict(X_trains)
y_pred_test_kmeans  = kmeans.predict(X_tests)

# %%
#Visualising the clusters Train set
fig, ax = plt.subplots(figsize=(6,4))
plt.scatter(X_trains[y_pred_train_kmeans == 0, 0], X_trains[y_pred_train_kmeans == 0, 1], s = 100, c = 'purple', label = 'Iris-setosa')
plt.scatter(X_trains[y_pred_train_kmeans == 1, 0], X_trains[y_pred_train_kmeans == 1, 1], s = 100, c = 'orange', label = 'Iris-versicolour')
plt.scatter(X_trains[y_pred_train_kmeans == 2, 0], X_trains[y_pred_train_kmeans == 2, 1], s = 100, c = 'green', label = 'Iris-virginica')

#Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s = 100, c = 'red', label = 'Centroids')

plt.legend()

# %%
#Visualising the clusters Test set
fig, ax = plt.subplots(figsize=(6,4))
plt.scatter(X_tests[y_pred_test_kmeans == 0, 0], X_tests[y_pred_test_kmeans == 0, 1], s = 100, c = 'purple', label = 'Iris-setosa')
plt.scatter(X_tests[y_pred_test_kmeans == 1, 0], X_tests[y_pred_test_kmeans == 1, 1], s = 100, c = 'orange', label = 'Iris-versicolour')
plt.scatter(X_tests[y_pred_test_kmeans == 2, 0], X_tests[y_pred_test_kmeans == 2, 1], s = 100, c = 'green', label = 'Iris-virginica')

#Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s = 100, c = 'red', label = 'Centroids')

plt.legend()

# %%
fig = plt.figure(figsize = (8,6))
ax = fig.add_subplot(111, projection='3d')
plt.scatter(X_tests[y_pred_test_kmeans == 0, 0], X_tests[y_pred_test_kmeans == 0, 1], s = 100, c = 'purple', label = 'Iris-setosa')
plt.scatter(X_tests[y_pred_test_kmeans == 1, 0], X_tests[y_pred_test_kmeans == 1, 1], s = 100, c = 'orange', label = 'Iris-versicolour')
plt.scatter(X_tests[y_pred_test_kmeans == 2, 0], X_tests[y_pred_test_kmeans == 2, 1], s = 100, c = 'green', label = 'Iris-virginica')
plt.legend(loc='upper right')
#Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s = 100, c = 'red', label = 'Centroids')
plt.show()

# %% [markdown]
# ### 9.6 Model Evaluation<a class="anchor" id="section96"></a>
# - Create a List of Accuracy and F 1 Scores
# - Append the lists for each model
# - Create a dataframe of Ml Model, Accuracy Score and F 1 Score
# - Compare the values and plot them to find the best model

# %%
# Creating the lists 
accuracy_score = []
f_1_score      = []

# %%
# Appending the list for both accuracy and F 1 Score
# Weighted avg is used to calculate F1 Score
# Note that repeatedly running the code increases the no of scores in the list for each iteration and will further
# issues wile creating DF as the # of Scores and # of models do not match.
# In case of reruns, create the list everytime afresh by running the code above.
accuracy_score.append(accuracy_score_logreg)
accuracy_score.append(accuracy_score_dt)
accuracy_score.append(accuracy_score_nb)
accuracy_score.append(accuracy_score_test_knn)

f_1_score.append(f1_score(y_test, y_pred_test_logreg, average='weighted'))
f_1_score.append(f1_score(y_test, y_pred_test_dt, average='weighted'))
f_1_score.append(f1_score(y_test, y_pred_test_nb, average='weighted'))
f_1_score.append(f1_score(y_test, y_pred_test_knn, average='weighted'))

# %%
print(accuracy_score)
print(f_1_score)
# Out:
# [0.9666666666666667, 0.9666666666666667, 0.9666666666666667, 0.9666666666666667]
# [0.9672820512820512, 0.9672820512820512, 0.9672820512820512, 0.9672820512820512]

# %%
# Creat dataframe from the models, accuracy score and F 1 Score
df_score = pd.DataFrame({"ML Models":["Logistic Regression",'Decison Tree','Naive Bayes', 'KNN'],"R2 Score":accuracy_score, "F 1 Score":f_1_score})

# %%
df_score
# Out:
#              ML Models  R2 Score  F 1 Score
# 0  Logistic Regression  0.966667   0.967282
# 1         Decison Tree  0.966667   0.967282
# 2          Naive Bayes  0.966667   0.967282
# 3                  KNN  0.966667   0.967282

# %%
# Plotting and Comparing the Model
df_score.groupby(['ML Models']).count().plot(kind='bar',stacked=False,figsize=(12,8),legend=True, cmap='flare');
plt.tick_params(axis="x", labelsize=14, labelcolor="purple", rotation = 0)
plt.xlabel('ML Models', fontweight='bold', fontsize = 14, color = 'blue')
plt.ylabel('Score', fontweight='bold', fontsize = 14, color = 'blue')
plt.title('Model Comparison', fontweight='bold', fontsize = 16, color = 'Red')
plt.legend(title='Score',bbox_to_anchor=(1, 1), ncol=1)

# %% [markdown]
# ### Observation
# - All the models created has similar accuracy and F 1 Score
# - Since accuracy of the models were high, hyper parameter tuning and using of Random Forest Classifer was avoided.

# %% [markdown]
# ## 10 Conclusion<a class="anchor" id="section10"></a>

# %% [markdown]
# ### 10.1 Summary<a class="anchor" id="section101"></a>
# - The project was conducted as per the project approch mentioned in section 3. Having done the project, it was seen that the data set presented a simple and straighforward need to classify the Iris flowers into three distict features using four attributes.
# - It was seen that the accuracy of test and train data was commensurate and hence there was no underfitting.
# - In this case the data was limited to just 150 rows and hence presented a low number of data points compared to other datsets. This could be one of the reasons for such high accuracy.
# - All models used got similar accuary and F 1 Score

# %% [markdown]
# ### 10.2 Limitations of Study<a class="anchor" id="section102"></a>
# - The data set used had only 150 rows out of which only 120 was used to do EDA and train models.
# - EDA was limited as the relation between the variables were fairly straight forward.

# %% [markdown]
# ### 10.3 Lessons Learned<a class="anchor" id="section103"></a>
# - Use of FacetGrid Plot
# - Use of Andrews Curve
# - Finer understanding of Python Code for ML Models
# - Better understanding of EDA and its relevence.

# %% [markdown]
# ## 11 Acknowledgement<a class="anchor" id="section11"></a>
# - The project would not have been sucessful without the able guidance of instructors at INSAID and members of the Cohort. There contribution to evaluating and impoving the code has gone a long way in undertsnding the integrites of Machine Learning.
# - thank you for the wonderful opportunity
